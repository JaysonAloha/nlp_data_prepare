# %%
# !pip install akshare --upgrade --upgrade-strategy eager
# Out:
# WARNING: Ignoring invalid distribution ~kshare (C:\Users\59240\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~kshare (C:\Users\59240\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~kshare (C:\Users\59240\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached akshare-1.17.80-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached akshare-1.17.80-py3-none-any.whl (1.1 MB)
# ...
#   Attempting uninstall: akshare
#     Found existing installation: akshare 1.17.71
#     Uninstalling akshare-1.17.71:
#       Successfully uninstalled akshare-1.17.71
# ...

# %%
import akshare as ak
realtime_data=ak.stock_zh_a_spot_em()

stock_data=realtime_data[realtime_data['代码'] == '000300'].iloc[0]
stock_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 import akshare as ak
# ----> 2 realtime_data=ak.stock_zh_a_spot_em(pn=1, pz=50)
#       4 stock_data=realtime_data[realtime_data['代码'] == '000300'].iloc[0]
#       5 stock_data
#
# TypeError: stock_zh_a_spot_em() got an unexpected keyword argument 'pn'
